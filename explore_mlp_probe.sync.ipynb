# %%
import os
import json
import random
from tqdm import tqdm
import numpy as np
from transformers import (
    GenerationConfig,
)
import torch
import torch.nn.functional as F
from fancy_einsum import einsum
import einops

from record_utils import record_activations, get_module
from hook_utils import HookWithCountThreshold
from explore_utils import *

# %%
cos = F.cosine_similarity

# %%
config = {
    "data_path": "data/train.parquet",
    "model_path": "checkpoints/TinyZero/v4/actor/global_step_300",
    "probe_path": "probe_checkpoints/probe_from_mlp/probe.pt",
    "batch_size": 64,
    "valid_size": 256,
    "max_prompt_length": 256,
    "max_response_length": 300,
    "n_layers": 36,
    "d_model": 2048,
    "seed": 42,
    "hook_config": {
        "hook_layers": list(range(24, 33)),
        "hook_target_char": " (",
        "hook_target_threshold": 0,
        "hook_scale": 20,
    },
}

seed_all(config["seed"])

# %%
actor = load_model(config["model_path"])
generation_config = GenerationConfig(do_sample=False)
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
_, valid_dataloader = get_dataloader(
    config["data_path"],
    config["batch_size"],
    config["max_prompt_length"],
    config["valid_size"],
    actor.tokenizer,
)
# Out:
# original dataset len: 327680
# filter dataset len: 327680

# %%
probe_model = torch.load(config["probe_path"]).detach().cuda()
probe_model.shape
# Out:
# /tmp/ipykernel_2479964/980249850.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   probe_model = torch.load(config["probe_path"]).detach().cuda()
# torch.Size([36, 2048, 2])

# %%
for layer_idx in range(probe_model.shape[0]):
    print(f"Layer {layer_idx}")
    print(cos(probe_model[layer_idx, :, 0], probe_model[layer_idx, :, 1], dim=0))

for layer_idx in range(probe_model.shape[0] - 1):
    print(f"Layer {layer_idx} vs. Layer {layer_idx + 1}")
    print(cos(probe_model[layer_idx, :, 1], probe_model[layer_idx + 1, :, 1], dim=0))
# Out:
# Layer 0
# tensor(-0.9433, device='cuda:0')
# Layer 1
# tensor(-0.9787, device='cuda:0')
# Layer 2
# tensor(-0.9791, device='cuda:0')
# Layer 3
# tensor(-0.9797, device='cuda:0')
# Layer 4
# tensor(-0.9839, device='cuda:0')
# Layer 5
# tensor(-0.9843, device='cuda:0')
# Layer 6
# tensor(-0.9832, device='cuda:0')
# Layer 7
# tensor(-0.9833, device='cuda:0')
# Layer 8
# tensor(-0.9835, device='cuda:0')
# Layer 9
# tensor(-0.9833, device='cuda:0')
# Layer 10
# tensor(-0.9830, device='cuda:0')
# Layer 11
# tensor(-0.9822, device='cuda:0')
# Layer 12
# tensor(-0.9827, device='cuda:0')
# Layer 13
# tensor(-0.9833, device='cuda:0')
# Layer 14
# tensor(-0.9841, device='cuda:0')
# Layer 15
# tensor(-0.9826, device='cuda:0')
# Layer 16
# tensor(-0.9848, device='cuda:0')
# Layer 17
# tensor(-0.9848, device='cuda:0')
# Layer 18
# tensor(-0.9848, device='cuda:0')
# Layer 19
# tensor(-0.9846, device='cuda:0')
# Layer 20
# tensor(-0.9847, device='cuda:0')
# Layer 21
# tensor(-0.9840, device='cuda:0')
# Layer 22
# tensor(-0.9837, device='cuda:0')
# Layer 23
# tensor(-0.9837, device='cuda:0')
# Layer 24
# tensor(-0.9848, device='cuda:0')
# Layer 25
# tensor(-0.9846, device='cuda:0')
# Layer 26
# tensor(-0.9841, device='cuda:0')
# Layer 27
# tensor(-0.9847, device='cuda:0')
# Layer 28
# tensor(-0.9845, device='cuda:0')
# Layer 29
# tensor(-0.9842, device='cuda:0')
# Layer 30
# tensor(-0.9836, device='cuda:0')
# Layer 31
# tensor(-0.9832, device='cuda:0')
# Layer 32
# tensor(-0.9832, device='cuda:0')
# Layer 33
# tensor(-0.9831, device='cuda:0')
# Layer 34
# tensor(-0.9827, device='cuda:0')
# Layer 35
# tensor(-0.9810, device='cuda:0')
# Layer 0 vs. Layer 1
# tensor(-0.0550, device='cuda:0')
# Layer 1 vs. Layer 2
# tensor(0.1309, device='cuda:0')
# Layer 2 vs. Layer 3
# tensor(0.0307, device='cuda:0')
# Layer 3 vs. Layer 4
# tensor(0.1541, device='cuda:0')
# Layer 4 vs. Layer 5
# tensor(0.0738, device='cuda:0')
# Layer 5 vs. Layer 6
# tensor(0.0513, device='cuda:0')
# Layer 6 vs. Layer 7
# tensor(0.0094, device='cuda:0')
# Layer 7 vs. Layer 8
# tensor(-0.0064, device='cuda:0')
# Layer 8 vs. Layer 9
# tensor(-0.0242, device='cuda:0')
# Layer 9 vs. Layer 10
# tensor(0.0532, device='cuda:0')
# Layer 10 vs. Layer 11
# tensor(-0.0350, device='cuda:0')
# Layer 11 vs. Layer 12
# tensor(-0.0542, device='cuda:0')
# Layer 12 vs. Layer 13
# tensor(-0.0758, device='cuda:0')
# Layer 13 vs. Layer 14
# tensor(-0.0379, device='cuda:0')
# Layer 14 vs. Layer 15
# tensor(-0.0506, device='cuda:0')
# Layer 15 vs. Layer 16
# tensor(-0.0322, device='cuda:0')
# Layer 16 vs. Layer 17
# tensor(-0.0186, device='cuda:0')
# Layer 17 vs. Layer 18
# tensor(-0.0725, device='cuda:0')
# Layer 18 vs. Layer 19
# tensor(-0.0192, device='cuda:0')
# Layer 19 vs. Layer 20
# tensor(-0.0406, device='cuda:0')
# Layer 20 vs. Layer 21
# tensor(-0.0556, device='cuda:0')
# Layer 21 vs. Layer 22
# tensor(-0.0802, device='cuda:0')
# Layer 22 vs. Layer 23
# tensor(-0.0777, device='cuda:0')
# Layer 23 vs. Layer 24
# tensor(-0.0655, device='cuda:0')
# Layer 24 vs. Layer 25
# tensor(-0.0267, device='cuda:0')
# Layer 25 vs. Layer 26
# tensor(-0.0361, device='cuda:0')
# Layer 26 vs. Layer 27
# tensor(-0.0809, device='cuda:0')
# Layer 27 vs. Layer 28
# tensor(-0.0585, device='cuda:0')
# Layer 28 vs. Layer 29
# tensor(-0.0350, device='cuda:0')
# Layer 29 vs. Layer 30
# tensor(-0.0326, device='cuda:0')
# Layer 30 vs. Layer 31
# tensor(0.0085, device='cuda:0')
# Layer 31 vs. Layer 32
# tensor(0.0608, device='cuda:0')
# Layer 32 vs. Layer 33
# tensor(0.0092, device='cuda:0')
# Layer 33 vs. Layer 34
# tensor(0.0254, device='cuda:0')
# Layer 34 vs. Layer 35
# tensor(0.0305, device='cuda:0')

# %%
def get_mlp_value_vecs(model):
    mlp_value_vecs = [layer.mlp.down_proj.weight for layer in model.model.layers]
    # [n_layers, d_mlp (11008), d_model (2048)]
    return torch.stack(mlp_value_vecs, dim=0)

# %%
value_vecs = get_mlp_value_vecs(actor)
print(value_vecs.shape)

top_cos_scores = {0: [], 1: []}
for target_label in [0, 1]:
    for layer_idx, target_probe_layer in enumerate(range(36)):
        target_probe = probe_model[target_probe_layer, :, target_label]

        print(f"Layer {target_probe_layer}")
        cos_scores = cos(value_vecs[target_probe_layer], target_probe.unsqueeze(-1), dim=0)
        _topk = cos_scores.topk(k=20)
        _values = [x.item() for x in _topk.values]
        _idxs = [x.item() for x in _topk.indices]
        topk = list(
            zip(
                _values,
                _idxs,
                [target_probe_layer] * _topk.indices.shape[0],
            )
        )
        top_cos_scores[target_label].extend(topk)

sorted_scores_0 = sorted(top_cos_scores[0], key=lambda x: x[0], reverse=True)
sorted_scores_1 = sorted(top_cos_scores[1], key=lambda x: x[0], reverse=True)
# Out:
# torch.Size([36, 2048, 11008])
# Layer 0
# Layer 1
# Layer 2
# Layer 3
# Layer 4
# Layer 5
# Layer 6
# Layer 7
# Layer 8
# Layer 9
# Layer 10
# Layer 11
# Layer 12
# Layer 13
# Layer 14
# Layer 15
# Layer 16
# Layer 17
# Layer 18
# Layer 19
# Layer 20
# Layer 21
# Layer 22
# Layer 23
# Layer 24
# Layer 25
# Layer 26
# Layer 27
# Layer 28
# Layer 29
# Layer 30
# Layer 31
# Layer 32
# Layer 33
# Layer 34
# Layer 35
# Layer 0
# Layer 1
# Layer 2
# Layer 3
# Layer 4
# Layer 5
# Layer 6
# Layer 7
# Layer 8
# Layer 9
# Layer 10
# Layer 11
# Layer 12
# Layer 13
# Layer 14
# Layer 15
# Layer 16
# Layer 17
# Layer 18
# Layer 19
# Layer 20
# Layer 21
# Layer 22
# Layer 23
# Layer 24
# Layer 25
# Layer 26
# Layer 27
# Layer 28
# Layer 29
# Layer 30
# Layer 31
# Layer 32
# Layer 33
# Layer 34
# Layer 35

# %%
seen = []
for elem in sorted_scores_0[:100]:
    cos_score, mlp_idx, probe_layer_idx = elem
    curr = (probe_layer_idx, mlp_idx)
    if curr in seen:
        continue
    seen.append(curr)
    print(curr)
    print(cos_score)
    print(
        unembed_text(
            actor.model.layers[probe_layer_idx].mlp.down_proj.weight[:, mlp_idx],
            actor.lm_head.weight,
            actor.tokenizer,
            k=10,
        )
    )
# Out:
# (0, 1426)
# 0.37973541021347046
# ['陉', '_FE', '愉', 'featured', ' span', 'riv', '荑', '-prev', 'oten', ' bre']
# (3, 5756)
# 0.2656635642051697
# [' Mey', '.flat', ' instructor', ' deferred', '蔑', ' Scratch', '包', ' flats', 'vasion', 'cipher']
# (2, 10899)
# 0.24624955654144287
# ['oxide', '.SDK', '旄', '.acquire', '.sdk', 'SES', 'ettle', 'Coeff', ' SDK', '斛']
# (2, 617)
# 0.24192531406879425
# ['-topic', '_signed', 'afs', 'ters', ' Weeks', '窨', 'topics', ' Signed', 'IGNED', 'ffa']
# (30, 6404)
# 0.241890549659729
# ['不是', '并非', ' not', '不是一个', '也不是', 'not', ' NOT', '\tnot', '并不是', '不再是']
# (22, 6443)
# 0.23765268921852112
# ['dex', 'heel', ' neck', 'edm', '脖', 'ベル', '增加值', 'ardu', '.evaluate', 'SYSTEM']
# (1, 3363)
# 0.22943776845932007
# ['眚', 'issan', 'ote', '出', ' ', ' out', '为中心', '', 'byter', ' by']
# (4, 7380)
# 0.22756074368953705
# ['\')"\n', '\xa0', '\'"\n', 'Dead', '\'")\n', '…\n', 'emia', 'oline', '\n', '死']
# (4, 2484)
# 0.2183368057012558
# ['uss', 'cap', ' carr', 'adir', ' Mats', ' Disc', 'os', ' cap', 'aged', 'ideos']
# (19, 8255)
# 0.21321529150009155
# ['olg', ' scal', ' paraph', 'ated', '传', ' reproduce', 'orama', 'énom', '分彩', '征信']
# (6, 9781)
# 0.21185345947742462
# ['ai', '一段', ' impro', '越', ' g', 'eper', '准则', ' Gold', 'gold', '倡']
# (8, 5645)
# 0.21021801233291626
# ['ioned', 'oint', '\n', '_layout', 'OK', 'inch', 'asto', 'arry', ' mù', 'ok']
# (2, 596)
# 0.20902694761753082
# ['unta', 'ond', ' PST', '办理', '验证', '牛', 'Msp', '游玩', ' Pt', ' PG']
# (6, 4550)
# 0.20743006467819214
# ['pire', 'rag', '鞠', ' hasher', '移', 'endar', 'elon', ' instantiation', '累', 'erate']
# (13, 477)
# 0.20569545030593872
# ['erval', '弄', '阳', '_aff', 'irmware', '切尔', 'erson', '髁', 'aff', 'cv']
# (1, 4816)
# 0.2054910510778427
# [' \n\n', ' score', ' indu', ' crow', '@a', ' &', 'inion', 'atomy', '-definition', ' branch']
# (0, 1779)
# 0.20443123579025269
# ['社会化', 'kel', '_-', 'Kel', '/+', 'fern', 'ties', ' �', ',array', ' Vader']
# (14, 6818)
# 0.20140725374221802
# ['처', 'hare', ' ver', '皤', 'ernen', 'ąż', '府', 'PATCH', 'existent', 'ance']
# (5, 3922)
# 0.20118828117847443
# ['okable', '指甲', '', 'phinx', '陷', ' integr', '精', '粘', '泥', ' ']
# (34, 3268)
# 0.19693487882614136
# [')', '}', ']', '"', "'", '”', '+)', '=}', '")', '[]}']
# (6, 9279)
# 0.19519680738449097
# [' sức', '镘', 'Abr', 'phinx', '.Xml', '泥', 'HEY', '.parsers', ' Abrams', 'fabs']
# (4, 4258)
# 0.1911913901567459
# ['sta', '能力', ' vo', 'ʲ', ' dang', ' ce', 'زا', 'orient', 'وا', ' coco']
# (1, 1058)
# 0.19112974405288696
# ['markt', 'agon', 'cer', 'apple', '��', 'iales', '平原', 'ukkan', '-plane', 'ervoir']
# (5, 10064)
# 0.18980494141578674
# ['荠', 'ñe', '打得', ' Saunders', '真爱', 'ioc', 'ampaign', '.defer', ' CommandType', '狻']
# (0, 9807)
# 0.18936806917190552
# ['其它问题', ' Bucc', '-mf', ' Ground', 'pire', 'ground', '-ground', ' ground', 'spir', ' Founder']
# (10, 792)
# 0.1887173056602478
# [' Platt', 'uje', 'CHA', '埠', '迎', 'args', ' rencont', 'uces', ' rencontr', 'obel']
# (5, 920)
# 0.18821948766708374
# ['ative', '<\\/', 'ellation', '\\xc', ' authority', '.sl', 'cons', 'q', '提', ' noqa']
# (24, 5159)
# 0.18488015234470367
# ['圬', 'ableObject', 'utow', 'lops', ' \n \n', 'enci', 'ENTE', 'バイ', '调', 'fce']
# (15, 1931)
# 0.1838604211807251
# ['看你', 'HAM', ' tracks', 'esome', '片', '(FALSE', 'leaflet', '背包', 'бар', 'Clusters']
# (2, 2193)
# 0.18079420924186707
# ['rlen', 'RE', ' repe', '鞴', 'rex', '◁', 'TestData', 'łó', 'rän', 'ABCDE']
# (3, 813)
# 0.17895717918872833
# [' prova', '悠悠', '輪', '�', 'isbury', '��', ' Cycling', ' Mé', ' Camping', ' mailed']
# (35, 402)
# 0.17815110087394714
# ['戤', '(GET', '攉', '锿', '镄', '蝘', '锩', 'أهد', '胩', '弆']
# (5, 3172)
# 0.17777051031589508
# ['ulin', 'gni', ' fashion', 'Given', '实质', ' Given', '樵', '硐', ' attachment', ' WARRANTIES']
# (6, 2876)
# 0.17596584558486938
# ['annt', '部长', ' agreg', '眼球', 'doll', 'flowers', ' Trend', ' Fl', '.amazon', 'POCH']
# (2, 502)
# 0.17454352974891663
# [' remotely', 'tie', 'cod', '线下', ' through', 'deb', ' ste', '.config', 'ads', 'aden']
# (6, 6298)
# 0.1736827939748764
# ['akra', '吒', 'ung', ' typings', 'AMS', ' brushed', ' Peb', '.libs', '맵', 'duction']
# (7, 4523)
# 0.17360450327396393
# ['��', 'loh', ' Qué', ' reflexivity', 'ode', 'uptime', '皇子', '性强', 'FILE', 'ên']
# (3, 4212)
# 0.17106133699417114
# ['...");\r\n', 'bose', 'cope', "...');\n", ' hos', 'ada', '...\r\n', 'uts', ' BOOT', "...',\n"]
# (3, 7036)
# 0.16853123903274536
# ['ktop', " '", 'individual', 'QP', ' individual', ' Kron', '开', '在家', '经开', ' saturn']
# (2, 10599)
# 0.16843825578689575
# ['iode', '谁知道', 'ング', 'jen', 'thouse', '家门口', 'Carbon', 'agus', 'ROID', 'Cod']
# (4, 3803)
# 0.16771408915519714
# ['avorite', 'entin', 'essa', '槿', 'oya', 'ERN', '动', ' Retro', 'rame', 'sess']
# (5, 7308)
# 0.16737836599349976
# ['眼角', 'assi', '.Pin', 'zia', 'angi', 'PTY', '&w', 'dera', ' Barry', '间的']
# (32, 67)
# 0.1663757860660553
# ['*l', '*s', '\xads', "'\\", ' cha', 't', '>(*', '\\-', 'da', '*d']
# (1, 8193)
# 0.1663322001695633
# [' barg', '这才', 'etc', 'śni', 'aksi', '锂', 'Thinking', 'IPPING', 'ços', ' hosts']
# (6, 5234)
# 0.16614601016044617
# [' caster', '******/', 'nown', '蕈', 'rag', '�', '斧', '冷却', 'vard', '杞']
# (14, 1504)
# 0.16540095210075378
# [' Dispatch', 'ello', 'hall', 'cart', ' Warfare', ' CART', '滑', '考点', ' ur', 'elry']
# (4, 7758)
# 0.1648847609758377
# [' Blueprint', 'crest', ' volume', ' volumes', 'anche', 'Carol', 'сад', ' Carol', 'фор', ' Cher']
# (14, 8792)
# 0.16415274143218994
# ['bose', '挽', ' Soros', '专享', 'aspers', ' above', ' dello', 'kaza', '纬', 'ataka']
# (4, 2990)
# 0.16390705108642578
# ['SB', '谵', 'mb', 'ymph', ' logarith', 'iqu', 'kb', ' mat', ' SB', ' ALOG']
# (24, 521)
# 0.16323643922805786
# ['乃至', '接着', 'unities', 'inue', '…and', '.decode', '搦', 'dana', '醭', '스크']
# (19, 8734)
# 0.16247621178627014
# ['致使', '酿', '无缘', '得不到', ' threatens', '严重', '.getResult', '会导致', ' Riv', '难免']
# (21, 6404)
# 0.16245333850383759
# ['orget', 'IVEN', 'phans', 'setter', 'razy', ' dying', 'SELL', 'riminator', 'inally', 'ifestyles']
# (19, 989)
# 0.1617358922958374
# ['识', '普', ' Wig', ' writ', '淼', ' however', 'poses', '煲', ' oran', ' kiện']
# (5, 5196)
# 0.16151602566242218
# ['.easy', ' hom', 'gles', ' Vice', ' tort', 'riot', 'mour', 'ewe', '>:</', '副']
# (5, 10665)
# 0.16110992431640625
# ['etary', 'owie', 'EDIA', '隧', 'ENTER', '萱', '蚓', 'etto', '션', '功课']
# (4, 2687)
# 0.16043981909751892
# ['oran', 'kt', 'chers', ' NHS', 'osph', '云', '/rc', '噪', 'VES', '/cc']
# (32, 1074)
# 0.1593962013721466
# ['…\n\n\n\n', '!.\n\n', '..\n\n\n\n', '...\n\n\n\n', ' ).\n\n', '...)\n\n', ' 请求', '".\n\n\n\n', ',...\n\n', '."\n\n\n\n']
# (1, 2700)
# 0.1586839258670807
# ['usat', 'erties', ' Option', 'fg', ' Card', 'option', 'getOption', 'Option', ' Rank', '翕']
# (6, 5813)
# 0.1583615392446518
# [' natural', '自然', ' bucket', ' buckets', ' benchmark', 'enton', 'loh', ' informational', 'natural', '沣']
# (6, 2420)
# 0.15834656357765198
# ['oko', 'complex', 'PropertyValue', 'elts', '"?\n\n', 'fter', ' Maintenance', ' puberty', ' complicated', ' complex']
# (19, 2496)
# 0.15823833644390106
# ['蛙', 'ir', ' sadly', 'очка', '的眼', '愧', '⇑', '媳', '滥用', '病']
# (5, 1373)
# 0.1572991907596588
# ['pure', 'Tracking', ' appearances', ' Kear', '_tracking', 'venue', '.bukkit', ' Tracking', ' NONINFRINGEMENT', 'LEAN']
# (9, 5940)
# 0.15657900273799896
# ['preci', ' Relevant', ' Extra', ' immedi', 'house', ' Tomorrow', '增添', 'herent', '高出', '上がり']
# (11, 4972)
# 0.15535876154899597
# ['_hub', 'ATRIX', ' printable', 'Hub', 'JNI', 'arrêt', ' ages', 'ished', 'ress', 'jec']
# (5, 2588)
# 0.1547885686159134
# ['fish', '的命运', 'shi', 'Messaging', '壁', ' module', ' moduleId', 'ড', 'icro', ' Modules']
# (35, 3181)
# 0.15376479923725128
# [' stockholm', 'LIBINT', ' invokevirtual', 'togroup', '-wsj', ".':", ' selber', ' ("/', '/mainwindow', '<LM']
# (32, 2020)
# 0.15364524722099304
# ['fläche', '匕', '讵', 'Ạ', ' smoothed', 'alytics', "']))", 'ServiceProvider', '(co', ' Bates']
# (14, 1623)
# 0.152728870511055
# ['的声音', 'dre', 'eced', '灰', ' Sahara', '前台', 'agr', 'uem', ' salv', 'acher']
# (6, 6061)
# 0.15237107872962952
# ['帔', 'íst', 'CAST', 'endar', 'ísticas', '愍', '酡', '-feed', '.appendTo', 'IFT']
# (0, 9955)
# 0.15164382755756378
# ['蝮', ' midi', ' Edition', '拳', 'Edition', 's', 'azel', 'ote', '{s', 'sword']
# (14, 327)
# 0.151484876871109
# [' closure', ' closing', '封闭', 'IDA', ' Closing', 'Closure', ' fut', '"label', ' engine', 'GF']
# (8, 7100)
# 0.1506146490573883
# ['ylon', ' pregn', 'uib', '.yy', ' gez', ' consc', 'Ｑ', 'gu', 'ELEMENT', 'gua']
# (1, 10416)
# 0.15053600072860718
# [' !");\n', 'LAG', 'スタッ', 'umber', 'ammable', 'amework', 'NST', ' !\n', ' nuru', 'ChangeEvent']
# (0, 7875)
# 0.14938879013061523
# ['性感', 'isActive', ' Dell', '的标准', '-any', '/false', ' Vinci', 'Ip', '的身体', ' mest']
# (16, 1160)
# 0.14930090308189392
# ['yll', '蕭', 'gien', 'routing', 'stad', 'TRACK', ' Duffy', 'bit', 'yh', ' Angelo']
# (0, 2478)
# 0.1477651298046112
# ['县委', 'rr', ' youngest', 'auc', ' Secretary', ' spare', 'DIRECT', '配套', 'rtle', 'python']
# (25, 4656)
# 0.14763140678405762
# ['', '返回搜狐', '凡本网', '有期', 'redit', 'vais', "');?>", 'Copyright', 'afety', 'oris']
# (6, 2650)
# 0.14593905210494995
# ['ye', 'SearchParams', ' Episodes', ' Metrics', '.nz', '本期', '堪', ' GetCurrent', '街', ' wield']
# (2, 9702)
# 0.1459088921546936
# ['Indented', 'mdp', 'Apple', ' Civic', ' McL', ' Apple', ' cons', 'rlen', '美的', '确']
# (6, 5975)
# 0.14526379108428955
# [' MEDIA', 'MEDIA', 'avl', 'media', '.MEDIA', ' penet', 'ENTA', 'don', 'pei', 'yw']
# (26, 6619)
# 0.14514979720115662
# ['缺乏', '缺少', '不方便', ' lacks', '难以', '未能', '无法', ' lack', '得不到', '不符合']
# (5, 1381)
# 0.14458602666854858
# ['wel', '�', '.getLine', ' EINA', 'g', 'inese', 'gars', '+w', 'егист', '线路']
# (4, 7164)
# 0.14410212635993958
# ['ny', ' –', '玛', ' Gardner', 'nz', '‘', '–', 'mans', ' gen', ' Prism']
# (24, 9679)
# 0.14320796728134155
# ['steller', 'argout', 'orz', '&action', 'peats', 'onaut', 'pcm', 'ainen', '好评', 'ソー']
# (2, 1014)
# 0.14314581453800201
# ['rouw', 'نو', '戟', '/setup', 'ignet', 'ENN', ' zro', 'DEN', 'TemplateName', 'atat']
# (0, 2081)
# 0.14119723439216614
# ['分钟左右', ' TERM', 'oples', ' Guid', 'сы', 'bau', ' THEORY', '_dic', 'phabet', '捻']
# (0, 8446)
# 0.1409536451101303
# ['utf', ' Tiny', ' UTF', 'ราย', ' dimin', 'Unit', '/product', ' Unit', 'tiny', ' Pope']
# (6, 7093)
# 0.14079433679580688
# [' Thur', 'ascus', 'omit', 'gings', 'tro', '保卫', 'omic', '亚军', 'apus', 'gie']
# (1, 3098)
# 0.14015844464302063
# ['ToOne', ' thừa', '.factor', 'ween', ' kick', '*@', '超级', ' Pit', ' 分', 'ún']
# (6, 10306)
# 0.13987666368484497
# [' orbits', 'rid', 'AGER', ' sider', ' Units', '!!.', ' bedside', ' später', 'poses', 'SIDE']
# (19, 3957)
# 0.13882490992546082
# ['-ed', 'resco', 'olta', '/******/\n', ' harm', '但他', '.reflect', '沉重', '瘕', '串']
# (10, 6287)
# 0.13871581852436066
# [' bumper', ' —\n\n', '⽅', ' 方', '},\r\n\r\n', '骢', 'ByPrimaryKey', ' Mär', '_between', '<Type']
# (4, 8342)
# 0.13866093754768372
# ['璎', 'acers', 'agr', ' Credential', '."</', '炀', '貌', '虓', 'minated', ' Creed']
# (4, 8957)
# 0.13788478076457977
# ['CID', '液', 'woff', 'mittel', 'cljs', '打猎', 'uy', ' المدني', '(dev', '宋体']
# (17, 2472)
# 0.13769251108169556
# ['>Action', ' IonicPage', 'ActionCode', 'ICI', 'ResultsController', '=<?', '...">\n', '行动计划', '渲', 'omm']
# (3, 10632)
# 0.13761314749717712
# ['allee', 'ixa', 'ules', 'Presentation', ' imm', 'pass', ' concurrently', 'ida', 'aset', ' pass']
# (17, 9429)
# 0.1376114934682846
# ['积分', '積', 'urus', '答', '积', ' Pillow', ' reviewers', 'tam', '_call', '镇党委']
# (4, 9714)
# 0.1374889314174652
# [' anale', '-io', 'CrLf', 'ër', '-hooks', ' trip', 'zer', ' s', '取决', '<?=$']
# (7, 8186)
# 0.13743475079536438
# [' \\\n', '\\\n', '...\\', '措', '"\\\n', ' transf', ' female', '女方', '\\xd', '郅']
# (13, 6630)
# 0.13689357042312622
# [' Phụ', 'ician', ' práctica', 'Trap', 'stry', 'Church', '屐', 'now', 'slots', ' prática']

# %%
seen = []
for elem in sorted_scores_1[:100]:
    cos_score, mlp_idx, probe_layer_idx = elem
    curr = (probe_layer_idx, mlp_idx)
    if curr in seen:
        continue
    seen.append(curr)
    print(curr)
    print(probe_layer_idx)
    print(cos_score)
    print(
        unembed_text(
            actor.model.layers[probe_layer_idx].mlp.down_proj.weight[:, mlp_idx],
            actor.lm_head.weight,
            actor.tokenizer,
            k=10,
        )
    )
# Out:
# (23, 3143)
# 23
# 0.4406369924545288
# ['闼', 'elif', ' piger', '.Suppress', '_BLOCKS', '锥', '煳', ' TSR', ' Thumb', 'hä']
# (26, 6475)
# 26
# 0.3136760890483856
# ['倒是', '不失', '适度', 'successful', '.success', '却是', ' successful', '没事', '完好', '还不错']
# (31, 4851)
# 31
# 0.30563002824783325
# ['CAF', 'bió', 'WithValue', 'PFN', 'isque', 'CTS', 'nda', ' المص', ' Tup', '("(%']
# (19, 5818)
# 19
# 0.28585493564605713
# ['不用担心', '大胆', '管', ' #{', '#{', ' feu', '愿意', ' cott', '_#{', ' %{']
# (1, 8025)
# 1
# 0.2599819004535675
# ['tip', ' Parkway', '-match', '进门', ' SAL', 'lage', 'zew', 'texts', ' nors', '_FUNCTIONS']
# (12, 10661)
# 12
# 0.2495301067829132
# ['nde', 'ndo', 'фин', ' Comple', 'PasswordField', '.prepareStatement', '.Complete', '喉', 'climate', '拉开']
# (26, 3665)
# 26
# 0.2468251883983612
# ['урс', 'swick', '然而', 'ulton', '最新', '�', '半个', 'iox', '然', '但是']
# (0, 1591)
# 0
# 0.23041090369224548
# ['ellant', 'lando', ' paying', 'ext', 'уществ', ' bench', '_escape', ' afterward', ' escape', ' landlord']
# (19, 9952)
# 19
# 0.2284160852432251
# ['大胆', ' urlString', '拄', '不存在', 'ningar', ' steep', ' Fischer', 'issance', '管', ' attenuation']
# (2, 7701)
# 2
# 0.2149481326341629
# ['辕', 'TY', 'Webpack', '\';";\n', 'modes', ' TY', '箪', '()];\n', '诸葛亮', ' *);\n']
# (33, 3509)
# 33
# 0.21124793589115143
# ['ivery', 'hot', 'hos', 'sst', 'elic', ' AppComponent', 'atoire', '浆', '.nodeType', 'Js']
# (5, 6644)
# 5
# 0.20997656881809235
# ['jom', '_)\r\n', '_);\r\n', '_\r\n\r\n', 'collect', ' бумаг', '当前位置', '_contract', '...\n\n\n\n\n\n', '何况']
# (2, 8685)
# 2
# 0.20911312103271484
# ['火花', 'asing', '_EOL', '', ' depress', '��', 'ataka', ' adel', ' Guaranteed', 'side']
# (6, 2407)
# 6
# 0.20688238739967346
# ['锶', ' Simmons', 'itori', 'PED', 'exclude', ' Conduct', '为核心', ' Zot', 'emarks', '.Free']
# (35, 6751)
# 35
# 0.20659208297729492
# ['}->', '\\:', '},"', '],&', '}[', '}};\n', ']\\\\', '},{"', '}\\\\', "]='"]
# (4, 4518)
# 4
# 0.20173092186450958
# [' Trophy', ' newText', 'centroid', 'awei', '\tNull', ' Mystic', '第九', 'toa', '倭', 'mage']
# (16, 8999)
# 16
# 0.20128405094146729
# [' paralle', 'Parallel', 'bundle', ' Parallel', '-best', 'sequ', ' sequ', '.serial', 'inf', ' aff']
# (25, 1124)
# 25
# 0.20114395022392273
# ['ELY', '怫', 'yes', ' Awesome', 'itchen', '没错', 'etur', '即时发生', 'ños', 'emade']
# (35, 1613)
# 35
# 0.1917431652545929
# ['}', '}}', '\u200b', '</', '}\\\\', '}}}', "']", '】', ')||', '?']
# (26, 8920)
# 26
# 0.1915110945701599
# [' greater', '过渡', '::', ' @', '只是', '##', 'icho', '更多', '更多的', '::_']
# (16, 9543)
# 16
# 0.18803882598876953
# [' LW', '傥', 'idth', 'apter', 'ibri', 'иф', ' Yapı', 'emean', '_SY', 'niest']
# (5, 6174)
# 5
# 0.18548151850700378
# ['高等院校', 'раб', 'Thunder', 'ns', ' Macros', 'views', ' [:', 'cors', ' Panels', '撞击']
# (5, 1967)
# 5
# 0.18534895777702332
# ['texts', ' Alv', '-sheet', ' commenting', 'ctl', 'meet', ' deb', '/***/', '成绩单', ' Administrator']
# (2, 6437)
# 2
# 0.1841256469488144
# ['lfw', ' Pett', '’an', 'SetActive', '翻', ' zun', 'GetPosition', ' ppl', 'ictory', '�']
# (3, 8222)
# 3
# 0.18326130509376526
# ['uchar', 'licity', 'ynes', 'iasm', '岞', 'monic', 'swers', 'osas', 'ocha', ' Raq']
# (30, 2041)
# 30
# 0.17968463897705078
# ['一体', '.addComponent', '俍', '椓', ' comparable', "$_['", '荒', '{-', 'addComponent', '僧']
# (22, 4606)
# 22
# 0.17945387959480286
# ['-banner', '<small', 'Rare', '(fin', '.bits', 'ocode', '大大小', 'lij', ' Finch', '_fin']
# (6, 7331)
# 6
# 0.1792728155851364
# ['itor', '渔', 'igi', 'њ', '/gl', '.getFile', '/~', 'sto', 'itori', '/pop']
# (1, 1023)
# 1
# 0.17851722240447998
# ['iju', ' COPYING', 'frey', 'очек', 'enum', 'stag', ' aft', ' Cert', ' resc', 'ans']
# (17, 1401)
# 17
# 0.17801818251609802
# ['，', 'tera', 'df', 'ENV', '笑', '籍', '.md', ' autom', 'yal', 'zd']
# (32, 1105)
# 32
# 0.17621031403541565
# ["([('", '정', '([(', ' props', '://"', 'thr', '\\.', 'etur', ' La', ')[-']
# (4, 1891)
# 4
# 0.17609068751335144
# ['亚马', 'esser', '杞', 'AGER', ' cooler', '�', 'ager', 'worth', 'hot', ' hot']
# (3, 1207)
# 3
# 0.17365384101867676
# ['人民', '⇨', '_normalize', 'richt', 'odyn', 'motion', '蘅', 'OLE', ').</', '椒']
# (2, 4419)
# 2
# 0.1730251908302307
# ['asm', ' SQ', 'tip', 'tm', ' tip', ' Squ', ' exile', ' erw', '-tip', ' Tutor']
# (35, 1512)
# 35
# 0.17298057675361633
# [',...\n', ',...\n\n', ',…\n\n', '–\n\n', '맴', 'Intialized', '使用網路', ' –\n\n', ' --\n\n', 'MemoryWarning']
# (2, 6102)
# 2
# 0.17292040586471558
# ['墟', ' tram', '...(', 'ilate', 'spiel', 'قام', 'зи', ' beaten', 'otel', '_GRA']
# (9, 3094)
# 9
# 0.1712115854024887
# ['posites', 'mont', 'mojom', 'uated', 'posite', 'ulaire', ' Pul', '.nl', '\\Cache', '状']
# (3, 3922)
# 3
# 0.17032037675380707
# ['pecified', 'annt', '.visual', '旒', 'GetName', 'äu', 'kdir', 'inent', 'licit', '荩']
# (19, 3356)
# 19
# 0.1687707006931305
# ['.Actions', 'Actions', '/actions', '-actions', 'Associated', '功劳', 'amarin', '岛上', 'ordinates', 'inde']
# (35, 8199)
# 35
# 0.16830749809741974
# ['uele', 'nis', '饥饿', '一路', 'wing', ' eas', 'illez', ' Wing', 'ucus', "'re"]
# (3, 2031)
# 3
# 0.16748151183128357
# ['ecycle', 'powers', 'izzo', 'WER', 'wers', 'UNS', '的权利', ' mạng', '的距离', ' powers']
# (9, 10626)
# 9
# 0.16666612029075623
# ['eenth', 'ermen', 'adar', 'ical', 'icals', 'ics', '茸', 'erman', 'ивается', 'URL']
# (33, 7733)
# 33
# 0.1654524803161621
# ['非', 'non', ' non', '并不会', ' Non', 'nu', 'Non', '无需', '(non', '并无']
# (33, 10604)
# 33
# 0.16337284445762634
# [' \xa0 \xa0', 'ffiti', 'ormap', ' \xa0', '笑笑', 'igar', '螨', 'Smarty', '}', ' clinically']
# (6, 4878)
# 6
# 0.16318091750144958
# ['mlin', 'ucher', 'ACA', 'ursion', 'ODB', '是我的', 'oha', 'DET', '上去', 'venience']
# (35, 7165)
# 35
# 0.16215813159942627
# ['1', 'italize', 'inate', 'opleft', ' Nug', '利物', 'ôm', ' flown', 'CTOR', 'ouse']
# (5, 5201)
# 5
# 0.16096431016921997
# [' reb', '-zone', ' storm', '_Version', 'iolet', 'helm', '我妈', 'вод', '蠹', 'OUN']
# (2, 7940)
# 2
# 0.16080710291862488
# ['鱼', 'igits', '鱼类', 'torrent', 'edin', 'arah', 'rength', ' Felix', '(vehicle', 'eland']
# (8, 10085)
# 8
# 0.16072978079319
# ['ippo', 'sono', '工夫', 'iveness', 'oley', 'nage', ' Mash', 'orphic', 'kest', '扳']
# (2, 5160)
# 2
# 0.16044160723686218
# [' Premiership', 'oute', ' Dough', '才发现', '日报记者', 'これら', '-transform', '这些东西', 'atrix', ' transformed']
# (5, 882)
# 5
# 0.1596142053604126
# ['multiply', '面上', 'iams', 'icans', 'oming', '_cv', '缛', 'vez', 'VOICE', 'افت']
# (35, 9112)
# 35
# 0.15949496626853943
# ['”.\n\n', '".\n\n\n\n', '?”\n\n', '").\n\n', ' ”\n\n', '”。\n\n', '."\n\n\n', '’.\n\n', ' """\r\n\r\n', '.*/\n']
# (25, 7384)
# 25
# 0.1591888666152954
# ['一定程度', '面积约', '值得一', '땅', 'ockets', 'كور', 'Conta', 'ordes', '�', '傍']
# (1, 9582)
# 1
# 0.15727411210536957
# ['.keySet', ' shells', '幺', 'OTP', 'olum', 'subtotal', 'ungan', 'emean', '的最大', 'eman']
# (6, 10358)
# 6
# 0.15704411268234253
# ['ColumnInfo', 'ublish', '常', '一级', '幺', 'iges', 'isation', '—all', ' butt', '堃']
# (19, 946)
# 19
# 0.15675827860832214
# ['嘛', '不用担心', 'igned', '发展目标', '邛', '褚', '=session', '.problem', '(forKey', '朕']
# (5, 4229)
# 5
# 0.15635327994823456
# ['一个多', '.gf', 'иона', '滹', 'amins', ' arma', '挹', 'AVA', ' dara', ' convin']
# (16, 9728)
# 16
# 0.15543833374977112
# ['客气', '毳', 'ɾ', '_MEDIA', '共同发展', '回去', 'pd', ' echoed', ' exaggerated', 'clamation']
# (4, 4160)
# 4
# 0.15519872307777405
# ['act', 'urate', ' comm', 'vez', 'ex', ' lamin', ' commissioned', 'PS', '星', 'tr']
# (9, 2449)
# 9
# 0.1537036895751953
# ['alon', ' rem', '荑', ' Rem', 'ctions', 'ounter', 'dess', 'ienie', 'Rem', '半夜']
# (0, 6279)
# 0
# 0.1534157693386078
# ['ableObject', '{}\\', ' varargin', 'ledo', 'agg', 'abilidad', 'ASY', '舛', ' Interracial', ' Conditioning']
# (33, 10621)
# 33
# 0.1532514989376068
# ['>,', ' [],', '”,', '】,', '**,', ' />,', '",', '%,', '],', '?,']
# (5, 9880)
# 5
# 0.15324528515338898
# ['ima', 'ⁿ', '=config', '大家分享', 'unts', 'modifiable', '不成', 'ESIS', 'rost', 'еча']
# (1, 2980)
# 1
# 0.15234676003456116
# ['ickets', 'aks', '蕃', 'stra', 'bury', 'ifa', '轻易', ' singly', ' undef', '枝']
# (13, 3566)
# 13
# 0.15144522488117218
# ['寮', 'IO', ' IO', ' EO', 'IEW', '燎', '-io', '_API', ' manufacture', 'brid']
# (5, 8816)
# 5
# 0.15039299428462982
# ['�性', 'ider', ' péri', 'haft', '<AM', 'ghi', 'rei', 'CAA', 'quit', '件']
# (1, 718)
# 1
# 0.15017445385456085
# ['息', 'link', 'erts', '盤', ' supplied', ' Links', 'vented', 'links', 'Links', 'ert']
# (34, 3135)
# 34
# 0.15005530416965485
# ['rtc', 'ikel', 'mods', 'imus', 'ceği', 'lds', ' rotterdam', ' kok', '.getRuntime', 'cola']
# (35, 4497)
# 35
# 0.14969128370285034
# ['()):\n', "'):\n", '):\n\n', '():\n', '():\n\n', '"):\n', ':");\n', '):\n', "']:\n", '"]:\n']
# (6, 3684)
# 6
# 0.14861953258514404
# ["'", '(mi', '列', 'есс', '象', 'inion', 'sss', '再', '在全球', '纠']
# (19, 6561)
# 19
# 0.1484730839729309
# ['аж', ' характеристик', ' involuntary', 'yu', 'ages', ' lateral', ' bald', '.descriptor', ' muff', 'aging']
# (19, 4804)
# 19
# 0.1479923129081726
# ['_pad', ' !***', 'serter', 'ape', '不负', ' AGAIN', 'Contract', ' cabo', '！\n\n\n\n', '组图']
# (19, 7725)
# 19
# 0.1471259444952011
# ['不用担心', 'uzzi', '没事', '大胆', '粲', ' Blank', '不住', ' Ferd', '单元', '工夫']
# (3, 8044)
# 3
# 0.1471155881881714
# ['ervo', 'labs', '-next', 'anos', ' postfix', '-prefix', 'Interop', 'ionario', ' pró', 'ernen']
# (10, 1948)
# 10
# 0.1464521884918213
# ['骈', 'nano', '_python', 'arto', ' pylint', '洋洋', 'noinspection', '�', '窍', ' pena']
# (14, 7694)
# 14
# 0.1460939347743988
# ['�名', '-pad', 'sembler', 'ascal', ' IonicModule', 'SURE', '胧', '/dialog', ' annotated', ' Shank']
# (2, 7396)
# 2
# 0.14522024989128113
# [' import', 'pal', 'uv', 'import', ' exp', 'irc', 'ume', ' vim', 'var', '@end']
# (5, 8120)
# 5
# 0.1449190080165863
# ['驳', '片', '-T', '郢', ' Advocate', '-mode', 'Mode', ' MEP', 'ycling', 'はず']
# (0, 4249)
# 0
# 0.1442076861858368
# ['UTOR', 'imulator', 'urga', 'istani', 'GORITHM', '服务商', 'efore', 'nite', 'OTH', 'nds']
# (25, 5582)
# 25
# 0.144158735871315
# ['呢', '呗', 'sek', 'nard', '王先生', 'ndl', ' tes', '的确', 'nels', '螫']
# (30, 838)
# 30
# 0.14385700225830078
# ['惟', ':boolean', ' sondern', '迳', ' juste', 'ahlen', 'verständ', '.LayoutInflater', '\tassertTrue', ' Ive']
# (32, 497)
# 32
# 0.14382784068584442
# ['"${', ' "${', ' ("%', '("${', '["$', '([{', "('${", '[${', " '{$", '="${']
# (16, 869)
# 16
# 0.14353854954242706
# ['-await', 'iram', ' cult', '醍', '一只手', 'ayar', 'YL', 'IOS', '陷', ' faces']
# (3, 8026)
# 3
# 0.14341823756694794
# [' Bris', '&q', '主', 'arLayout', '办公', 'ar', ' office', 'office', 'łą', '.SharedPreferences']
# (5, 7927)
# 5
# 0.14337143301963806
# ["'http", '[Unit', 'SOLE', 'DEL', '"http', '_Handle', '.?', 'rete', '口中', '=Value']
# (10, 1646)
# 10
# 0.14310218393802643
# [' Bullet', 'lator', '薄弱', 'ych', ' off', '网红', 'igh', ' rest', '琉', '鬲']
# (12, 555)
# 12
# 0.1431010216474533
# ['裸', '\xa0\n', '...\\', ' \\\n', '...\n\n\n\n', ' ...\n\n\n\n', '...\n\n\n', ':I', '...\n\n', 'ondo']
# (4, 3512)
# 4
# 0.14284788072109222
# ['dì', 'gre', '.setLocation', '最基本的', 'gt', '最基本', 'icone', 'turnstile', 'ailer', '相关信息']
# (14, 529)
# 14
# 0.14263561367988586
# ['heets', 'enk', '五官', 'SEE', '觱', 'isme', ' zoom', 'ɲ', 'APPLICATION', 'ussen']
# (2, 4896)
# 2
# 0.14251279830932617
# ['arest', ' Trib', 'amentos', '夺取', '-tip', 'quire', '中央', 'Leading', '枣', ' compensated']
# (19, 5437)
# 19
# 0.14210085570812225
# [' *)(', 'APO', 'elry', ' fills', 'modele', 'yne', '))^', 'fill', ' fill', '茆']
# (25, 5423)
# 25
# 0.14200648665428162
# [' Accepted', ' interface', '~-', '孟', 'vented', '臾', 'sist', ' Sink', 'BuilderInterface', ' iface']
# (3, 8127)
# 3
# 0.14179019629955292
# ['咫', 'rz', '戗', '.Cluster', '_translate', 'utch', 'udy', ' Normalize', ' Arn', 'ịch']
# (6, 5343)
# 6
# 0.14157402515411377
# ['lex', '|r', '保安', 'iew', 'ior', ' Canary', '.GetChild', '.GetInt', '经商', '蕤']
# (3, 2060)
# 3
# 0.14140494167804718
# ['amer', '特', 'apus', '貔', 'ATUS', 'PILE', 'amerate', 'video', 'ship', ' vide']
# (8, 777)
# 8
# 0.1410256326198578
# ['贤', 'amba', 'ǁ', 'hall', 'share', '退', '¹', '獬', '\ttyp', '庶']
# (5, 5586)
# 5
# 0.14069300889968872
# ['orio', 'quit', 'inium', 'eyer', 'imity', 'ью', 'abcdefghijklmnop', 'oria', 'peats', '.operator']
# (26, 4334)
# 26
# 0.14023786783218384
# ['iston', 'StackSize', 'ISIBLE', 'てくれ', '|int', 'ут', '几分', ' TER', 'TERN', '藻']
# (35, 1907)
# 35
# 0.1400901973247528
# ['。\n\n', '.\n\n', '?\n\n', '!\n\n', '！\n\n', '？\n\n', '.\n\n\n', '.\n\n\n\n', '?\n\n\n', '!\n\n\n']
# (25, 1039)
# 25
# 0.1389213502407074
# ['�', '更有', '更为', '讨', '胜', '接管', ' Regents', ')..', ' hơn', ' viewpoint']
